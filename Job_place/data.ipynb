# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\Lenovo\OneDrive\Documents\Data set\MLL\Job_Placement_Data.csv")

# %%
df.head(3)
# Out:
#   gender  ssc_percentage ssc_board  hsc_percentage hsc_board hsc_subject  \
# 0      M           67.00    Others           91.00    Others    Commerce
# 1      M           79.33   Central           78.33    Others     Science
# 2      M           65.00   Central           68.00   Central        Arts
#
#    degree_percentage undergrad_degree work_experience  emp_test_percentage  \
# 0              58.00         Sci&Tech              No                 55.0
# 1              77.48         Sci&Tech             Yes                 86.5
# 2              64.00        Comm&Mgmt              No                 75.0
#
#   specialisation  mba_percent  status
# 0         Mkt&HR        58.80  Placed
# 1        Mkt&Fin        66.28  Placed
# 2        Mkt&Fin        57.80  Placed

# %% [markdown]
# # preprocess

# %%
df.shape
# Out:
# (215, 13)

# %%
df.isnull().sum()
# Out:
# gender                 0
# ssc_percentage         0
# ssc_board              0
# hsc_percentage         0
# hsc_board              0
# hsc_subject            0
# degree_percentage      0
# undergrad_degree       0
# work_experience        0
# emp_test_percentage    0
# specialisation         0
# mba_percent            0
# status                 0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   gender               215 non-null    object
#  1   ssc_percentage       215 non-null    float64
#  2   ssc_board            215 non-null    object
#  3   hsc_percentage       215 non-null    float64
#  4   hsc_board            215 non-null    object
#  5   hsc_subject          215 non-null    object
#  6   degree_percentage    215 non-null    float64
#  7   undergrad_degree     215 non-null    object
#  8   work_experience      215 non-null    object
#  9   emp_test_percentage  215 non-null    float64
#  10  specialisation       215 non-null    object
#  11  mba_percent          215 non-null    float64
#  12  status               215 non-null    object
# dtypes: float64(5), object(8)
# memory usage: 22.0+ KB

# %%
df.describe()
# Out:
#        ssc_percentage  hsc_percentage  degree_percentage  emp_test_percentage  \
# count      215.000000      215.000000         215.000000           215.000000
# mean        67.303395       66.333163          66.370186            72.100558
# std         10.827205       10.897509           7.358743            13.275956
# min         40.890000       37.000000          50.000000            50.000000
# 25%         60.600000       60.900000          61.000000            60.000000
# 50%         67.000000       65.000000          66.000000            71.000000
# 75%         75.700000       73.000000          72.000000            83.500000
# max         89.400000       97.700000          91.000000            98.000000
#
#        mba_percent
# count   215.000000
# mean     62.278186
# std       5.833385
# min      51.210000
# 25%      57.945000
# 50%      62.000000
# 75%      66.255000
# max      77.890000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   gender               215 non-null    object
#  1   ssc_percentage       215 non-null    float64
#  2   ssc_board            215 non-null    object
#  3   hsc_percentage       215 non-null    float64
#  4   hsc_board            215 non-null    object
#  5   hsc_subject          215 non-null    object
#  6   degree_percentage    215 non-null    float64
#  7   undergrad_degree     215 non-null    object
#  8   work_experience      215 non-null    object
#  9   emp_test_percentage  215 non-null    float64
#  10  specialisation       215 non-null    object
#  11  mba_percent          215 non-null    float64
#  12  status               215 non-null    object
# dtypes: float64(5), object(8)
# memory usage: 22.0+ KB

# %% [markdown]
# # EDA

# %%
plt.hist(df['ssc_percentage'],bins=20)
plt.title('SSC percentage Distribution')
plt.xlabel('Percentage')
plt.ylabel('Count')
plt.show()

# %%
plt.hist(df['hsc_percentage'],bins=20)
plt.title('hsc percentage Distribution')
plt.xlabel('Percentage')
plt.ylabel('Count')
plt.show()

# %%
gender_counts = df['gender'].value_counts()

plt.bar(gender_counts.index, gender_counts.values)
plt.xlabel('Gender')
plt.ylabel('Count')
plt.title('Gender Distribution')
plt.show()

# %% [markdown]
# ### Education Boards (SSC & HSC)

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 5))
sns.countplot(x='ssc_board', data=df, ax=ax[0])
ax[0].set_title("SSC Board Distribution")

sns.countplot(x='hsc_board', data=df, ax=ax[1])
ax[1].set_title("HSC Board Distribution")

plt.show()

# %%
#S pecialisation (MBA)

sns.countplot(x='specialisation', data=df)
plt.title("MBA Specialisation Distribution")
plt.show()

# %%
# how marks/percentages are spread
numeric_cols = ['ssc_percentage', 'hsc_percentage', 'degree_percentage', 'emp_test_percentage', 'mba_percent']
df[numeric_cols].hist(figsize=(12, 8), bins=15, color='skyblue')
plt.suptitle("Distribution of Percentages", fontsize=16)
plt.show()
